# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import MobileNetV2
from keras.layers import AveragePooling2D, Dropout, Flatten, Dense, Input, GlobalAveragePooling2D, Conv2D, MaxPooling2D
from keras import regularizers
from keras.models import Model, Sequential
from keras.optimizers import Adam
from keras.applications.mobilenet_v2 import preprocess_input
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
import pickle
import os
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import cv2
# Out:
# Using plaidml.keras.backend backend.

# %%
def get_pickles():
    combined_dict = pickle.load(open('../Pickles/TTSDict.p', 'rb'))
    
    x_train = combined_dict['train']['images']
    x_test = combined_dict['test']['images']
    
    y_train = combined_dict['train']['labels']
    y_test = combined_dict['test']['labels']
    
    validation = combined_dict['validation']
    
    return x_train, x_test, y_train, y_test, validation 

x_train, x_test, y_train, y_test, validation  = get_pickles()

# %%
print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (10000, 250, 250, 3) (992, 250, 250, 3)
# (10000, 2) (992, 2)

# %%
def get_conv_model(dim):
    '''This function will create and compile a CNN given the input dimension'''
    inp_shape = dim
    act = 'relu'
    drop = .25
    kernal_reg = regularizers.l1(.001)
    optimizer = Adam(lr = .0001)
    
    model = Sequential() 
    
    model.add(Conv2D(64, kernel_size=(3,3),activation=act, input_shape = inp_shape, 
                     kernel_regularizer = kernal_reg,
                     kernel_initializer = 'he_uniform',  padding = 'same', name = 'Input_Layer'))
    model.add(MaxPooling2D(pool_size=(2, 2),  strides = (3,3)))
    
    
    model.add(Conv2D(64, (3, 3), activation=act, kernel_regularizer = kernal_reg, 
                     kernel_initializer = 'he_uniform',padding = 'same'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides = (3,3)))
    

    
    model.add(Conv2D(128, (3, 3), activation=act, kernel_regularizer = kernal_reg, 
                     kernel_initializer = 'he_uniform',padding = 'same'))
    model.add(Conv2D(128, (3, 3), activation=act, kernel_regularizer = kernal_reg, 
                     kernel_initializer = 'he_uniform',padding = 'same'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides = (3,3)))

    model.add(Flatten())

    
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))

    model.add(Dropout(drop))

    model.add(Dense(2, activation='sigmoid', name = 'Output_Layer'))
    
    model.compile(loss = 'binary_crossentropy', optimizer = optimizer, metrics = ['accuracy'])
    return model

# %%
early_stopping = EarlyStopping(monitor='val_loss', verbose = 1, patience=10, min_delta = .00075)
model_checkpoint = ModelCheckpoint('ModelWeights/Normal1.h5', verbose = 1, save_best_only=True,
                                  monitor = 'val_loss')
lr_plat = ReduceLROnPlateau(patience = 5, mode = 'min')
epochs = 2000
batch_size = 100
    

dim = (x_train.shape[1], x_train.shape[2], x_train.shape[3])
normal_model = get_conv_model(dim =dim)

    
augmentation =ImageDataGenerator(rotation_range = 20, width_shift_range = .2, height_shift_range = .2, 
                                                       horizontal_flip = True, shear_range = .15, 
                                 fill_mode = 'nearest', zoom_range = .15)
augmentation.fit(x_train)
normal_history = normal_model.fit_generator(augmentation.flow(x_train, y_train, batch_size = batch_size),
            epochs = epochs, 
     callbacks = [early_stopping, model_checkpoint, lr_plat], validation_data = (x_test, y_test), verbose= 1)
# Out:
# INFO:plaidml:Opening device "opencl_amd_ellesmere.0"
# Epoch 1/2000
# INFO:plaidml:Analyzing Ops: 91 of 395 operations complete
# 100/100 [==============================] - 118s 1s/step - loss: 10.9131 - acc: 0.7653 - val_loss: 9.7655 - val_acc: 0.9173
#
# Epoch 00001: val_loss improved from inf to 9.76555, saving model to ModelWeights/Normal1.h5
# Epoch 2/2000
# 100/100 [==============================] - 104s 1s/step - loss: 9.0291 - acc: 0.9031 - val_loss: 8.2133 - val_acc: 0.9360
#
# Epoch 00002: val_loss improved from 9.76555 to 8.21333, saving model to ModelWeights/Normal1.h5
# Epoch 3/2000
# 100/100 [==============================] - 110s 1s/step - loss: 7.5780 - acc: 0.9255 - val_loss: 6.8846 - val_acc: 0.9415
#
# Epoch 00003: val_loss improved from 8.21333 to 6.88458, saving model to ModelWeights/Normal1.h5
# Epoch 4/2000
# 100/100 [==============================] - 113s 1s/step - loss: 6.3501 - acc: 0.9317 - val_loss: 5.7484 - val_acc: 0.9521
#
# Epoch 00004: val_loss improved from 6.88458 to 5.74837, saving model to ModelWeights/Normal1.h5
# Epoch 5/2000
# 100/100 [==============================] - 110s 1s/step - loss: 5.3118 - acc: 0.9356 - val_loss: 4.7928 - val_acc: 0.9577
#
# Epoch 00005: val_loss improved from 5.74837 to 4.79279, saving model to ModelWeights/Normal1.h5
# Epoch 6/2000
# 100/100 [==============================] - 115s 1s/step - loss: 4.4551 - acc: 0.9392 - val_loss: 4.0322 - val_acc: 0.9551
#
# Epoch 00006: val_loss improved from 4.79279 to 4.03218, saving model to ModelWeights/Normal1.h5
# Epoch 7/2000
# 100/100 [==============================] - 114s 1s/step - loss: 3.7744 - acc: 0.9445 - val_loss: 3.4416 - val_acc: 0.9647
#
# Epoch 00007: val_loss improved from 4.03218 to 3.44159, saving model to ModelWeights/Normal1.h5
# Epoch 8/2000
# 100/100 [==============================] - 119s 1s/step - loss: 3.2767 - acc: 0.9429 - val_loss: 3.0252 - val_acc: 0.9597
#
# Epoch 00008: val_loss improved from 3.44159 to 3.02525, saving model to ModelWeights/Normal1.h5
# Epoch 9/2000
# 100/100 [==============================] - 115s 1s/step - loss: 2.8967 - acc: 0.9475 - val_loss: 2.7207 - val_acc: 0.9572
#
# Epoch 00009: val_loss improved from 3.02525 to 2.72074, saving model to ModelWeights/Normal1.h5
# Epoch 10/2000
# 100/100 [==============================] - 114s 1s/step - loss: 2.6206 - acc: 0.9486 - val_loss: 2.4756 - val_acc: 0.9647
#
# Epoch 00010: val_loss improved from 2.72074 to 2.47556, saving model to ModelWeights/Normal1.h5
# Epoch 11/2000
# 100/100 [==============================] - 110s 1s/step - loss: 2.4234 - acc: 0.9500 - val_loss: 2.2864 - val_acc: 0.9708
#
# Epoch 00011: val_loss improved from 2.47556 to 2.28643, saving model to ModelWeights/Normal1.h5
# Epoch 12/2000
# 100/100 [==============================] - 110s 1s/step - loss: 2.2617 - acc: 0.9515 - val_loss: 2.1501 - val_acc: 0.9698
#
# Epoch 00012: val_loss improved from 2.28643 to 2.15011, saving model to ModelWeights/Normal1.h5
# Epoch 13/2000
# 100/100 [==============================] - 110s 1s/step - loss: 2.1236 - acc: 0.9562 - val_loss: 2.0326 - val_acc: 0.9687
#
# Epoch 00013: val_loss improved from 2.15011 to 2.03264, saving model to ModelWeights/Normal1.h5
# Epoch 14/2000
# 100/100 [==============================] - 110s 1s/step - loss: 2.0146 - acc: 0.9508 - val_loss: 1.9129 - val_acc: 0.9708
#
# Epoch 00014: val_loss improved from 2.03264 to 1.91291, saving model to ModelWeights/Normal1.h5
# Epoch 15/2000
# 100/100 [==============================] - 109s 1s/step - loss: 1.9063 - acc: 0.9543 - val_loss: 1.8151 - val_acc: 0.9728
#
# Epoch 00015: val_loss improved from 1.91291 to 1.81514, saving model to ModelWeights/Normal1.h5
# Epoch 16/2000
# 100/100 [==============================] - 110s 1s/step - loss: 1.8127 - acc: 0.9568 - val_loss: 1.7453 - val_acc: 0.9637
#
# Epoch 00016: val_loss improved from 1.81514 to 1.74526, saving model to ModelWeights/Normal1.h5
# Epoch 17/2000
# 100/100 [==============================] - 111s 1s/step - loss: 1.7275 - acc: 0.9569 - val_loss: 1.6514 - val_acc: 0.9687
#
# Epoch 00017: val_loss improved from 1.74526 to 1.65135, saving model to ModelWeights/Normal1.h5
# Epoch 18/2000
# 100/100 [==============================] - 113s 1s/step - loss: 1.6478 - acc: 0.9583 - val_loss: 1.5736 - val_acc: 0.9713
#
# Epoch 00018: val_loss improved from 1.65135 to 1.57364, saving model to ModelWeights/Normal1.h5
# Epoch 19/2000
# 100/100 [==============================] - 111s 1s/step - loss: 1.5777 - acc: 0.9581 - val_loss: 1.5168 - val_acc: 0.9652
#
# Epoch 00019: val_loss improved from 1.57364 to 1.51678, saving model to ModelWeights/Normal1.h5
# Epoch 20/2000
# 100/100 [==============================] - 110s 1s/step - loss: 1.5121 - acc: 0.9583 - val_loss: 1.4577 - val_acc: 0.9622
#
# Epoch 00020: val_loss improved from 1.51678 to 1.45773, saving model to ModelWeights/Normal1.h5
# Epoch 21/2000
# 100/100 [==============================] - 110s 1s/step - loss: 1.4510 - acc: 0.9577 - val_loss: 1.3945 - val_acc: 0.9672
#
# Epoch 00021: val_loss improved from 1.45773 to 1.39455, saving model to ModelWeights/Normal1.h5
# Epoch 22/2000
# 100/100 [==============================] - 111s 1s/step - loss: 1.3985 - acc: 0.9588 - val_loss: 1.3320 - val_acc: 0.9723
#
# Epoch 00022: val_loss improved from 1.39455 to 1.33196, saving model to ModelWeights/Normal1.h5
# Epoch 23/2000
# 100/100 [==============================] - 111s 1s/step - loss: 1.3431 - acc: 0.9590 - val_loss: 1.2830 - val_acc: 0.9748
#
# Epoch 00023: val_loss improved from 1.33196 to 1.28302, saving model to ModelWeights/Normal1.h5
# Epoch 24/2000
# 100/100 [==============================] - 112s 1s/step - loss: 1.2931 - acc: 0.9622 - val_loss: 1.2413 - val_acc: 0.9738
#
# Epoch 00024: val_loss improved from 1.28302 to 1.24129, saving model to ModelWeights/Normal1.h5
# Epoch 25/2000
# 100/100 [==============================] - 111s 1s/step - loss: 1.2524 - acc: 0.9592 - val_loss: 1.1981 - val_acc: 0.9723
#
# Epoch 00025: val_loss improved from 1.24129 to 1.19806, saving model to ModelWeights/Normal1.h5
# Epoch 26/2000
# 100/100 [==============================] - 110s 1s/step - loss: 1.2097 - acc: 0.9587 - val_loss: 1.1523 - val_acc: 0.9748
#
# Epoch 00026: val_loss improved from 1.19806 to 1.15228, saving model to ModelWeights/Normal1.h5
# Epoch 27/2000
# 100/100 [==============================] - 111s 1s/step - loss: 1.1676 - acc: 0.9616 - val_loss: 1.1163 - val_acc: 0.9713
#
# Epoch 00027: val_loss improved from 1.15228 to 1.11634, saving model to ModelWeights/Normal1.h5
# Epoch 28/2000
# 100/100 [==============================] - 110s 1s/step - loss: 1.1296 - acc: 0.9612 - val_loss: 1.0785 - val_acc: 0.9733
#
# Epoch 00028: val_loss improved from 1.11634 to 1.07846, saving model to ModelWeights/Normal1.h5
# Epoch 29/2000
# 100/100 [==============================] - 110s 1s/step - loss: 1.0915 - acc: 0.9619 - val_loss: 1.0419 - val_acc: 0.9743
#
# Epoch 00029: val_loss improved from 1.07846 to 1.04195, saving model to ModelWeights/Normal1.h5
# Epoch 30/2000
# 100/100 [==============================] - 111s 1s/step - loss: 1.0559 - acc: 0.9643 - val_loss: 1.0140 - val_acc: 0.9743
#
# Epoch 00030: val_loss improved from 1.04195 to 1.01400, saving model to ModelWeights/Normal1.h5
# Epoch 31/2000
# 100/100 [==============================] - 110s 1s/step - loss: 1.0266 - acc: 0.9655 - val_loss: 0.9797 - val_acc: 0.9763
#
# Epoch 00031: val_loss improved from 1.01400 to 0.97966, saving model to ModelWeights/Normal1.h5
# Epoch 32/2000
# 100/100 [==============================] - 111s 1s/step - loss: 1.0000 - acc: 0.9616 - val_loss: 0.9572 - val_acc: 0.9743
#
# Epoch 00032: val_loss improved from 0.97966 to 0.95719, saving model to ModelWeights/Normal1.h5
# Epoch 33/2000
# 100/100 [==============================] - 111s 1s/step - loss: 0.9717 - acc: 0.9646 - val_loss: 0.9312 - val_acc: 0.9718
#
# Epoch 00033: val_loss improved from 0.95719 to 0.93123, saving model to ModelWeights/Normal1.h5
# Epoch 34/2000
# 100/100 [==============================] - 111s 1s/step - loss: 0.9471 - acc: 0.9608 - val_loss: 0.9103 - val_acc: 0.9662
#
# Epoch 00034: val_loss improved from 0.93123 to 0.91033, saving model to ModelWeights/Normal1.h5
# Epoch 35/2000
# 100/100 [==============================] - 110s 1s/step - loss: 0.9216 - acc: 0.9634 - val_loss: 0.8747 - val_acc: 0.9768
#
# Epoch 00035: val_loss improved from 0.91033 to 0.87473, saving model to ModelWeights/Normal1.h5
# Epoch 36/2000
# 100/100 [==============================] - 112s 1s/step - loss: 0.8986 - acc: 0.9624 - val_loss: 0.8654 - val_acc: 0.9698
#
# Epoch 00036: val_loss improved from 0.87473 to 0.86540, saving model to ModelWeights/Normal1.h5
# Epoch 37/2000
# 100/100 [==============================] - 111s 1s/step - loss: 0.8783 - acc: 0.9635 - val_loss: 0.8371 - val_acc: 0.9682
#
# Epoch 00037: val_loss improved from 0.86540 to 0.83705, saving model to ModelWeights/Normal1.h5
# Epoch 38/2000
# 100/100 [==============================] - 110s 1s/step - loss: 0.8528 - acc: 0.9656 - val_loss: 0.8149 - val_acc: 0.9713
#
# Epoch 00038: val_loss improved from 0.83705 to 0.81488, saving model to ModelWeights/Normal1.h5
# Epoch 39/2000
# 100/100 [==============================] - 112s 1s/step - loss: 0.8312 - acc: 0.9643 - val_loss: 0.8059 - val_acc: 0.9698
#
# Epoch 00039: val_loss improved from 0.81488 to 0.80588, saving model to ModelWeights/Normal1.h5
# Epoch 40/2000
# 100/100 [==============================] - 111s 1s/step - loss: 0.8085 - acc: 0.9681 - val_loss: 0.7729 - val_acc: 0.9773
#
# Epoch 00040: val_loss improved from 0.80588 to 0.77292, saving model to ModelWeights/Normal1.h5
# Epoch 41/2000
# 100/100 [==============================] - 113s 1s/step - loss: 0.7905 - acc: 0.9666 - val_loss: 0.7549 - val_acc: 0.9743
#
# Epoch 00041: val_loss improved from 0.77292 to 0.75494, saving model to ModelWeights/Normal1.h5
# Epoch 42/2000
# 100/100 [==============================] - 110s 1s/step - loss: 0.7767 - acc: 0.9658 - val_loss: 0.7627 - val_acc: 0.9577
#
# Epoch 00042: val_loss did not improve from 0.75494
# Epoch 43/2000
# 100/100 [==============================] - 109s 1s/step - loss: 0.7581 - acc: 0.9650 - val_loss: 0.7204 - val_acc: 0.9768
#
# Epoch 00043: val_loss improved from 0.75494 to 0.72037, saving model to ModelWeights/Normal1.h5
# Epoch 44/2000
# 100/100 [==============================] - 111s 1s/step - loss: 0.7441 - acc: 0.9661 - val_loss: 0.7266 - val_acc: 0.9647
#
# Epoch 00044: val_loss did not improve from 0.72037
# Epoch 45/2000
# 100/100 [==============================] - 110s 1s/step - loss: 0.7277 - acc: 0.9645 - val_loss: 0.6881 - val_acc: 0.9763
#
# Epoch 00045: val_loss improved from 0.72037 to 0.68806, saving model to ModelWeights/Normal1.h5
# Epoch 46/2000
# 100/100 [==============================] - 111s 1s/step - loss: 0.7155 - acc: 0.9639 - val_loss: 0.6814 - val_acc: 0.9758
#
# Epoch 00046: val_loss improved from 0.68806 to 0.68137, saving model to ModelWeights/Normal1.h5
# Epoch 47/2000
# 100/100 [==============================] - 110s 1s/step - loss: 0.6966 - acc: 0.9650 - val_loss: 0.6717 - val_acc: 0.9728
#
# Epoch 00047: val_loss improved from 0.68137 to 0.67170, saving model to ModelWeights/Normal1.h5
# Epoch 48/2000
# 100/100 [==============================] - 110s 1s/step - loss: 0.6869 - acc: 0.9668 - val_loss: 0.6514 - val_acc: 0.9763
#
# Epoch 00048: val_loss improved from 0.67170 to 0.65137, saving model to ModelWeights/Normal1.h5
# Epoch 49/2000
# 100/100 [==============================] - 111s 1s/step - loss: 0.6759 - acc: 0.9643 - val_loss: 0.6395 - val_acc: 0.9768
#
# Epoch 00049: val_loss improved from 0.65137 to 0.63948, saving model to ModelWeights/Normal1.h5
# Epoch 50/2000
# 100/100 [==============================] - 110s 1s/step - loss: 0.6655 - acc: 0.9641 - val_loss: 0.6239 - val_acc: 0.9798
#
# Epoch 00050: val_loss improved from 0.63948 to 0.62389, saving model to ModelWeights/Normal1.h5
# Epoch 51/2000
# 100/100 [==============================] - 111s 1s/step - loss: 0.6493 - acc: 0.9684 - val_loss: 0.6271 - val_acc: 0.9713
#
# Epoch 00051: val_loss did not improve from 0.62389
# Epoch 52/2000
# 100/100 [==============================] - 110s 1s/step - loss: 0.6353 - acc: 0.9688 - val_loss: 0.6086 - val_acc: 0.9748
#
# Epoch 00052: val_loss improved from 0.62389 to 0.60858, saving model to ModelWeights/Normal1.h5
# Epoch 53/2000
# 100/100 [==============================] - 111s 1s/step - loss: 0.6302 - acc: 0.9659 - val_loss: 0.6041 - val_acc: 0.9743
#
# Epoch 00053: val_loss improved from 0.60858 to 0.60412, saving model to ModelWeights/Normal1.h5
# Epoch 54/2000
# 100/100 [==============================] - 111s 1s/step - loss: 0.6170 - acc: 0.9669 - val_loss: 0.5883 - val_acc: 0.9738
#
# Epoch 00054: val_loss improved from 0.60412 to 0.58826, saving model to ModelWeights/Normal1.h5
# Epoch 55/2000
# 100/100 [==============================] - 111s 1s/step - loss: 0.6030 - acc: 0.9687 - val_loss: 0.5828 - val_acc: 0.9743
#
# Epoch 00055: val_loss improved from 0.58826 to 0.58278, saving model to ModelWeights/Normal1.h5
# Epoch 56/2000
# 100/100 [==============================] - 111s 1s/step - loss: 0.6016 - acc: 0.9653 - val_loss: 0.5676 - val_acc: 0.9743
#
# Epoch 00056: val_loss improved from 0.58278 to 0.56761, saving model to ModelWeights/Normal1.h5
# Epoch 57/2000
#  19/100 [====>.........................] - ETA: 1:23 - loss: 0.6010 - acc: 0.9632

# %%
assert False

# %% [markdown]
# ### Mobilenet

# %%
def get_mobilenet(dim):
    model = Sequential()
    optimizer = Adam(lr = .0005)
    baseModel = MobileNetV2(weights="imagenet", include_top=False,
        input_tensor=Input(shape=dim))
    
    model.add(baseModel)
    model.add(AveragePooling2D(pool_size=(7, 7)))
    model.add(Flatten(name="flatten"))
    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.3))
    model.add(Dense(2, activation="sigmoid", name = 'Output'))

    
    for layer in baseModel.layers:
        layer.trainable = False
        
    model.compile(loss = 'binary_crossentropy', optimizer = optimizer, metrics = ['accuracy'])
    return model

# %%
early_stopping = EarlyStopping(monitor='val_loss', verbose = 1, patience=10, min_delta = .00075)
model_checkpoint = ModelCheckpoint('ModelWeights/Mobilenet1.h5', verbose = 1, save_best_only=True,
                                  monitor = 'val_loss')
lr_plat = ReduceLROnPlateau(patience = 5, mode = 'min')
epochs = 2000
batch_size = 32
    

dim = (x_train.shape[1], x_train.shape[2], x_train.shape[3])
mobilenet = get_mobilenet(dim =dim)

    
augmentation =ImageDataGenerator(rotation_range = 20, width_shift_range = .2, height_shift_range = .2, 
                                                       horizontal_flip = True, shear_range = .15, 
                                 fill_mode = 'nearest', zoom_range = .15)
augmentation.fit(x_train)
mobilenet_history = mobilenet.fit_generator(augmentation.flow(x_train, y_train, batch_size = batch_size),
            epochs = epochs, 
     callbacks = [early_stopping, model_checkpoint, lr_plat], validation_data = (x_test, y_test), verbose= 1)
